# %% [markdown]
# This dataset contains five attributes Sepal_length,Sepal_width,Petal_length,Petal_width and Species. Here we predict the species of Iris flower using the sepal_length,sepal_width,petal_length and petal_width. We have three varieties of species. They are Iris-virginica,Iris-setosa and Iris-versicolor
#
# ![Iris_flowers.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Importing Essential Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Loading Dataset**

# %%
df=pd.read_csv('/content/IRIS.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **Data Preprocessing**

# %%
#First 5 values
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#Last 5 values
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
#Total rows and columns
df.shape
# Out:
# (150, 5)

# %%
#Datatype of each columns
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
from IPython.display import Image
from IPython.display import display
display(Image(filename='/content/Iris_flowers.jpeg',height=400,width=800))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# **Checking null values**

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# **Data Visualization**

# %%
plt.figure(figsize=(8,5))
plt.suptitle("Distribution of Iris Flower Species",weight="bold",fontsize=22)
count=df['species'].value_counts().values
colors=['yellow','green','blue']
plt.subplot(1,2,1)
ax=sns.countplot(x=df['species'],palette=colors)
plt.subplot(1,2,2)
labels=['Iris-versicolor','Iris-virginica','Iris-setosa']
plt.pie(count,colors=colors,autopct='%1.1f%%')
plt.legend(labels=labels,loc=(0.9,0.2))

# %%
color_palette={'virginica':'red','setosa':'green','versicolor':'blue'}
sns.set_palette(list(color_palette.values()))
sns.pairplot(data=df,hue='species',height=3)

# %%
correlation_matrix=df.corr()
sns.heatmap(correlation_matrix,linecolor='white',linewidth=1)
plt.title("Correlation Heatmap of Iris Dataset")
plt.show()
# Out:
# <ipython-input-25-ac8af34223a7>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix=df.corr()

# %% [markdown]
# Separating X and Y

# %%
x=df.iloc[:,:-1].values

# %%
y=df.iloc[:,-1].values
y
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
# ...

# %% [markdown]
# **Model Selection:**
#
# train_test_split:Evaluate the performance of a model on unseen data. It involves dividing dataset into training set and testing set.

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
#Training data=70% & testing data=30%

# %% [markdown]
# Random state-setting random state=42 ensures reproducability and consistent results in ML algorithms that involve randomness.

# %%
x_train
# Out:
# array([[5.5, 2.4, 3.7, 1. ],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.4, 3.1, 5.5, 1.8],
#        [6.6, 3. , 4.4, 1.4],
#        [7.2, 3.6, 6.1, 2.5],
#        [5.7, 2.9, 4.2, 1.3],
#        [7.6, 3. , 6.6, 2.1],
#        [5.6, 3. , 4.5, 1.5],
#        [5.1, 3.5, 1.4, 0.2],
#        [7.7, 2.8, 6.7, 2. ],
#        [5.8, 2.7, 4.1, 1. ],
#        [5.2, 3.4, 1.4, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [5.1, 3.8, 1.9, 0.4],
#        [5. , 2. , 3.5, 1. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.1, 3.4, 1.5, 0.2],
#        [5.7, 3. , 4.2, 1.2],
#        [7.7, 3.8, 6.7, 2.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.7, 2.5, 5. , 2. ],
#        [5.5, 4.2, 1.4, 0.2],
#        [6. , 3. , 4.8, 1.8],
#        [5.8, 2.7, 5.1, 1.9],
#        [6. , 2.2, 4. , 1. ],
#        [5.4, 3. , 4.5, 1.5],
#        [6.2, 3.4, 5.4, 2.3],
# ...

# %%
y_train
# Out:
# array(['Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)
#Used to transform the variables of a dataset to a common range.
#Range varies between 0 & 1.

# %%
x_train
# Out:
# array([[-0.4134164 , -1.46440146, -0.10014569, -0.32149987],
#        [ 0.55122187, -0.49582097,  0.71771076,  0.35364985],
#        [ 0.67180165,  0.2306144 ,  0.95138404,  0.75873969],
#        [ 0.91296121, -0.01153072,  0.30878254,  0.21861991],
#        [ 1.63643991,  1.44134002,  1.30189395,  1.7039493 ],
#        [-0.17225683, -0.25367584,  0.1919459 ,  0.08358997],
#        [ 2.11875905, -0.01153072,  1.59398554,  1.16382952],
#        [-0.29283662, -0.01153072,  0.36720086,  0.35364985],
#        [-0.89573553,  1.19919489, -1.443767  , -1.40173942],
#        [ 2.23933883, -0.49582097,  1.65240385,  1.02879957],
#        [-0.05167705, -0.73796609,  0.13352758, -0.32149987],
#        [-0.77515575,  0.95704977, -1.443767  , -1.40173942],
#        [-1.01631531,  1.19919489, -1.50218532, -1.26670948],
#        [-0.89573553,  1.92563026, -1.15167541, -1.13167953],
#        [-1.01631531, -2.43298195, -0.21698232, -0.32149987],
# ...

# %% [markdown]
# **Algorithms**

# %%
from sklearn.tree import DecisionTreeClassifier
#Creating object
dec=DecisionTreeClassifier()
dec.fit(x_train,y_train)
#Predicting using the test data
y_pred=dec.predict(x_test)
#Calculating accuracy
from sklearn.metrics import accuracy_score,classification_report
print("Decision Tree Accuracy:",accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Decision Tree Accuracy: 0.9555555555555556
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      0.85      0.92        13
#  Iris-virginica       0.87      1.00      0.93        13
#
#        accuracy                           0.96        45
#       macro avg       0.96      0.95      0.95        45
#    weighted avg       0.96      0.96      0.96        45

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report
rf=RandomForestClassifier(n_estimators=100,random_state=42)
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)
#Calculating Accuracy
print("Random Forest Accuracy:",accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Random Forest Accuracy: 0.9777777777777777
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.93      1.00      0.96        13
#
#        accuracy                           0.98        45
#       macro avg       0.98      0.97      0.97        45
#    weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# **Confusion Matrix**

# %% [markdown]
# A confusion matrix is an N x N matrix that is used to evaluate the performance of a classification model, where N is the number of target classes. It compares the actual target values against the ones predicted by ML model

# %%
from sklearn.metrics import confusion_matrix
matrix=confusion_matrix(y_test,y_pred)
print(matrix)
# Out:
# [[19  0  0]
#  [ 0 12  1]
#  [ 0  0 13]]

# %%
from sklearn.metrics import ConfusionMatrixDisplay
label=['Iris-versicolor','Iris-virginica','Iris-setosa']
cmd=ConfusionMatrixDisplay(matrix,display_labels=label)
cmd.plot()

# %%
from sklearn import tree
plt.figure(figsize=(12,12))
names=['sepal_length','sepal_width','petal_length','petal_width']
tree.plot_tree(dec,feature_names=names,class_names=['Iris-versicolor','Iris-virginica','Iris-setosa'])
# Out:
# [Text(0.3076923076923077, 0.9285714285714286, 'petal_length <= -0.83\ngini = 0.664\nsamples = 105\nvalue = [31, 37, 37]\nclass = Iris-virginica'),
#  Text(0.23076923076923078, 0.7857142857142857, 'gini = 0.0\nsamples = 31\nvalue = [31, 0, 0]\nclass = Iris-versicolor'),
#  Text(0.38461538461538464, 0.7857142857142857, 'petal_length <= 0.513\ngini = 0.5\nsamples = 74\nvalue = [0, 37, 37]\nclass = Iris-virginica'),
#  Text(0.15384615384615385, 0.6428571428571429, 'petal_width <= 0.489\ngini = 0.059\nsamples = 33\nvalue = [0, 32, 1]\nclass = Iris-virginica'),
#  Text(0.07692307692307693, 0.5, 'gini = 0.0\nsamples = 32\nvalue = [0, 32, 0]\nclass = Iris-virginica'),
#  Text(0.23076923076923078, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Iris-setosa'),
#  Text(0.6153846153846154, 0.6428571428571429, 'petal_width <= 0.691\ngini = 0.214\nsamples = 41\nvalue = [0, 5, 36]\nclass = Iris-setosa'),
# ...

# %% [markdown]
# **THANK YOU**
